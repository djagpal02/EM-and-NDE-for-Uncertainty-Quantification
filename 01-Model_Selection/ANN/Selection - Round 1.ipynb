# %%
import sys
sys.path.insert(0, '../../Models/ANN')

# %%
from ANN import ANN
import pandas as pd

# %%
x = pd.read_csv('../../Data/Missing_0_Mask/X_train_0.csv')
y = pd.read_csv('../../Data/Y_train.csv')
xt = pd.read_csv('../../Data/Missing_0_Mask/X_test_0.csv')
yt = pd.read_csv('../../Data/Y_test.csv')

# %%
# Top 1 Layer ANN F1 Score
Model1 = ANN([26,199,12], 'tanh', 0.05)
Model1.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model1')
# Out:
# Device is cuda:0.
# Finishing last run (ID:lhoun4ib) before initializing another...
# <br/>Waiting for W&B process to finish, PID 89976... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 1 Layer ANN Accuracy
Model1_2 = ANN([26,58,12], 'tanh', 0.1227)
Model1_2.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model1')
# Out:
# Device is cuda:0.
# Finishing last run (ID:14sdl05p) before initializing another...
# <br/>Waiting for W&B process to finish, PID 91045... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 1 Layer ANN Accuracy - Unbalanced classes
Model1_3 = ANN([26,58,12], 'tanh', 0.1227)
Model1_3.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model1')
# Out:
# Device is cuda:0.
# Finishing last run (ID:2zt5lkhn) before initializing another...
# <br/>Waiting for W&B process to finish, PID 93055... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 2 Layer ANN F1 Score
Model2 = ANN([26,229,491,12], 'leaky_relu', 0.08)
Model2.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model2')
# Out:
# Device is cuda:0.
# Finishing last run (ID:s2r38zso) before initializing another...
# Successfully finished last run (ID:s2r38zso). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/2djagpal/Lithology-ANN_Model2/runs/3b9uir9y" target="_blank">neat-sponge-1</a></strong> to <a href="https://wandb.ai/2djagpal/Lithology-ANN_Model2" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.44199328327542414 ... Score: -1.6919018702088233
#
# Validation:
# Epoch: 1 ... Accuracy: 0.2829967979179156 ... Score: -2.2502887722427736
#
# Training:
# Epoch: 2 ... Accuracy: 0.4494763398208133 ... Score: -1.639714727157626
#
# Validation:
# Epoch: 2 ... Accuracy: 0.26446419955258577 ... Score: -2.2698576608717267
#
# Training:
# Epoch: 3 ... Accuracy: 0.5163830156230911 ... Score: -1.3980620429880626
# ...

# %%
# Top 2 Layer ANN Accuracy
Model2_2 = ANN([26,135,21,12], 'tanh', 0.1116)
Model2_2.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model2')
# Out:
# Device is cuda:0.
# Finishing last run (ID:2e0f4c3l) before initializing another...
# <br/>Waiting for W&B process to finish, PID 98326... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train_batch_loss</td><td>▄▃▂▃▁▇▅▅▃▂▃▃▄▃▁▆▆▆▄▄▄▁▄▂▂▅▄▃▆▅▅▃▅▆▆▂▆▄▅█</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_batch_loss</td><td>1.28108</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# ...

# %%
# Top 2 Layer ANN Accuracy - Unbalanced classes
Model2_3 = ANN([26,135,21,12], 'tanh', 0.1116)
Model2_3.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model2')
# Out:
# Device is cuda:0.
# Finishing last run (ID:324d8foz) before initializing another...
# <br/>Waiting for W&B process to finish, PID 98472... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 2 Layer ANN Accuracy - Increased Dropout
Model2_4 = ANN([26,135,21,12], 'tanh', 0.5)
Model2_4.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model2')
# Out:
# Device is cuda:0.
# wandb: Currently logged in as: 2djagpal (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/2djagpal/Lithology-ANN_Model2/runs/lkso0azc" target="_blank">smart-sky-6</a></strong> to <a href="https://wandb.ai/2djagpal/Lithology-ANN_Model2" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6169655816989332 ... Score: -1.1437391446983411
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6205971371339172 ... Score: -1.1337646031026567
#
# Training:
# Epoch: 2 ... Accuracy: 0.6262512697445817 ... Score: -1.0772023928010928
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6238357726667934 ... Score: -1.0675873261883526
#
# Training:
# Epoch: 3 ... Accuracy: 0.6465560767903933 ... Score: -1.016527717381554
#
# Validation:
# ...

# %%
# Top 2 Layer ANN Accuracy - Increased Weight decay
Model2_5 = ANN([26,135,21,12], 'tanh', 0.1116)
Model2_5.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.3, n_epoch = 100, batchsize = 256, run_name='Model2')
# Out:
# Device is cuda:0.
# Finishing last run (ID:lkso0azc) before initializing another...
# <br/>Waiting for W&B process to finish, PID 101696... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 3 Layer ANN F1 Score
Model3 = ANN([26,457,383,71,12], 'tanh', 0.04)
Model3.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model3')
# Out:
# Device is cuda:0.
# Finishing last run (ID:2hdfa4ee) before initializing another...
# <br/>Waiting for W&B process to finish, PID 102889... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 3 Layer ANN Accuracy
Model3_2 = ANN([26,376,342,85,12], 'tanh', 0.1259)
Model3_2.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model3')
# Out:
# Device is cuda:0.
# Finishing last run (ID:3eu2rpe5) before initializing another...
# <br/>Waiting for W&B process to finish, PID 104303... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 3 Layer ANN Accuracy - 2
Model3_3 = ANN([26,115,83,11,12], 'tanh', 0.3511)
Model3_3.fit( x=x, y=y, xt = xt, yt = yt, lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model3')
# Out:
# Device is cuda:0.
# Finishing last run (ID:kpdfv5q6) before initializing another...
# <br/>Waiting for W&B process to finish, PID 106048... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# Top 3 Layer ANN Accuracy - Unbalanced
Model3_4 = ANN([26,376,342,85,12], 'tanh', 0.1259)
Model3_4.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model3')
# Out:
# Device is cuda:0.
# Finishing last run (ID:3c2dnuxq) before initializing another...
# <br/>Waiting for W&B process to finish, PID 106803... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# ...

# %%
# MODEL TRAINED BUT CELL CLEARED - DATA AVAILABLE IN WANDB #
# Top 3 Layer ANN Accuracy - Unbalanced + lr reduction
Model3_5 = ANN([26,376,342,85,12], 'tanh', 0.1259)
Model3_5.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 256, run_name='Model3')
