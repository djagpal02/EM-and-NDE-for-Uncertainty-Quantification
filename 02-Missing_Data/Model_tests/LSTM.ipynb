# %%
import sys
sys.path.insert(0, '../../Models/LSTM')

# %%
from LSTM import LSTM
import pandas as pd
import torch
import utils
import numpy as np

# %%
A = np.load('../penalty_matrix.npy')

# %%
y = pd.read_csv('../../Data/Y_train.csv')
yt = pd.read_csv('../../Data/Y_test.csv')

# %%
# 0
x = pd.read_csv('../../Data/Missing_0_Mask/X_train_0_WELL.csv')
xt = pd.read_csv('../../Data/Missing_0_Mask/X_test_0_WELL.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = False, active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6347988186356215 ... Score: -1.0741449674543853
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6332153875396604 ... Score: -1.0879064743467899
#
# Training:
# Epoch: 2 ... Accuracy: 0.7011228429292847 ... Score: -0.8316803515729455
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6771891860278099 ... Score: -0.9362635796061001
#
# Training:
# Epoch: 3 ... Accuracy: 0.7173883884901552 ... Score: -0.7692670124415747
#
# Validation:
# Epoch: 3 ... Accuracy: 0.7138157413770415 ... Score: -0.7975331905311948
#
# Training:
# Epoch: 4 ... Accuracy: 0.7080232479660593 ... Score: -0.79647371959768
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6927463336891202 ... Score: -0.8635386662377729
#
# Training:
# Epoch: 5 ... Accuracy: 0.7313011154957109 ... Score: -0.7197633127753605
#
# Validation:
# Epoch: 5 ... Accuracy: 0.73295512698668 ... Score: -0.7275470442881582
#
# Training:
# ...

# %%
# KNN - k=50
x = pd.read_csv('../../Data/Missing_KNN/X_train_50_well.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_50_C_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = True, savemodelroot = './bestmodels/RNN', run_name = 'KNN', active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6834852470416767 ... Score: -0.895099661600788
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6932288392086909 ... Score: -0.8782733613089059
#
# Training:
# Epoch: 2 ... Accuracy: 0.7164272697992586 ... Score: -0.7704187530061657
#
# Validation:
# Epoch: 2 ... Accuracy: 0.7139473337914699 ... Score: -0.7950594359071835
#
# Training:
# Epoch: 3 ... Accuracy: 0.7217035978303493 ... Score: -0.7613296671282884
#
# Validation:
# Epoch: 3 ... Accuracy: 0.7297311128331847 ... Score: -0.7502887722427733
#
# Training:
# Epoch: 4 ... Accuracy: 0.6878115626422989 ... Score: -0.8445548568104017
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6296185282119515 ... Score: -1.0362290365973126
#
# Training:
# Epoch: 5 ... Accuracy: 0.7385124958244732 ... Score: -0.6930594842765254
#
# Validation:
# Epoch: 5 ... Accuracy: 0.7342052549237496 ... Score: -0.72582994604711
#
# Training:
# ...

# %%
params = torch.load('./bestmodels/RNN/KNN/bestmodel.pth')
Model.set_params(params)

# Training Accuracy
Model.score(x,y)
# Out:
# Parameters Loaded
# 0.8347516597451882

# %%
# Missing Mean
x = pd.read_csv('../../Data/Missing_Mean/X_train_well.csv')
xt = pd.read_csv('../../Data/Missing_Mean/X_test_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None,  savemodel = True, savemodelroot = './bestmodels/RNN', run_name = 'Mean', active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.661084774085848 ... Score: -0.980246875082763
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6612518825025953 ... Score: -0.9893273068881319
#
# Training:
# Epoch: 2 ... Accuracy: 0.6992134204633703 ... Score: -0.84407782156682
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6819849984647551 ... Score: -0.9215700071644759
#
# Training:
# Epoch: 3 ... Accuracy: 0.7131141868807725 ... Score: -0.7847328004606535
#
# Validation:
# Epoch: 3 ... Accuracy: 0.7105259310163321 ... Score: -0.8018684295176407
#
# Training:
# Epoch: 4 ... Accuracy: 0.703194587662995 ... Score: -0.8178345825028556
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6626555349231646 ... Score: -0.9580448657026304
#
# Training:
# Epoch: 5 ... Accuracy: 0.7194011846108238 ... Score: -0.760754384196304
#
# Validation:
# Epoch: 5 ... Accuracy: 0.7190428845057243 ... Score: -0.762059896480634
#
# Training:
# ...

# %%
params = torch.load('./bestmodels/RNN/Mean/bestmodel.pth')
Model.set_params(params)

# Training Accuracy
Model.score(x,y)
# Out:
# Parameters Loaded
# 0.8302348290618371

# %%
# Missing MICE
x = pd.read_csv('../../Data/Missing_MICE/X_train_preTrain_well.csv')
xt = pd.read_csv('../../Data/Missing_MICE/X_test_preTrain_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None,  savemodel = True, savemodelroot = './bestmodels/RNN', run_name = 'MICE', active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6398034704500855 ... Score: -1.0384739015694855
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6335224365066601 ... Score: -1.0642490825084439
#
# Training:
# Epoch: 2 ... Accuracy: 0.7067075832691876 ... Score: -0.8077462535593429
#
# Validation:
# Epoch: 2 ... Accuracy: 0.7036173292588422 ... Score: -0.8343123565277148
#
# Training:
# Epoch: 3 ... Accuracy: 0.7184716760457612 ... Score: -0.7685362418635964
#
# Validation:
# Epoch: 3 ... Accuracy: 0.7146418493120641 ... Score: -0.7945385492667378
#
# Training:
# Epoch: 4 ... Accuracy: 0.7325518512854642 ... Score: -0.7102653242899896
#
# Validation:
# Epoch: 4 ... Accuracy: 0.732216747327943 ... Score: -0.7168323147105697
#
# Training:
# Epoch: 5 ... Accuracy: 0.7289508599235719 ... Score: -0.7229993994076092
#
# Validation:
# Epoch: 5 ... Accuracy: 0.7120538651616394 ... Score: -0.7689346862983054
#
# Training:
# ...

# %%
params = torch.load('./bestmodels/RNN/MICE/bestmodel.pth')
Model.set_params(params)

# Training Accuracy
Model.score(x,y)

# %%
# 0.842523479061709
