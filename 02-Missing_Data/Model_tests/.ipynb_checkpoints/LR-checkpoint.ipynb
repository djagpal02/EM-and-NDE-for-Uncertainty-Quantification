# %%
import sys
sys.path.insert(0, '../../Models/ANN')

# %%
from ANN import ANN
import pandas as pd
import torch
import numpy as np
import utils
A = np.load('../penalty_matrix.npy')

# %%
y = pd.read_csv('../../Data/Y_train.csv')
yt = pd.read_csv('../../Data/Y_test.csv')

# %%
# KNN - k = 5
x = pd.read_csv('../../Data/Missing_KNN/X_train_5.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_5_C.csv')

LR = ANN([26,12], None, 0, device = "cuda:3")
LR.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# Device is cuda:3.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.5310296101446291 ... Score: -1.324844021115564
#
# Validation:
# Epoch: 1 ... Accuracy: 0.5583539251092948 ... Score: -1.2498135774128931
#
# Training:
# Epoch: 2 ... Accuracy: 0.6021865663799828 ... Score: -1.1471597661192419
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6108885412249792 ... Score: -1.1204874767885602
#
# Training:
# Epoch: 3 ... Accuracy: 0.6332465051588579 ... Score: -1.0732275262684416
#
# Validation:
# Epoch: 3 ... Accuracy: 0.6470983872618543 ... Score: -1.0241819338236369
#
# Training:
# Epoch: 4 ... Accuracy: 0.6476325297241974 ... Score: -1.0312923159201408
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6696372435775592 ... Score: -0.9591323307940871
#
# Training:
# Epoch: 5 ... Accuracy: 0.6595820116171484 ... Score: -0.9914376071647341
#
# Validation:
# Epoch: 5 ... Accuracy: 0.6874899478016756 ... Score: -0.9025530756071528
#
# Training:
# ...

# %%
# KNN - k = 50
x = pd.read_csv('../../Data/Missing_KNN/X_train_50.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_50_C.csv')

LR = ANN([26,12], None, 0, device = "cuda:3")
LR.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# Device is cuda:3.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.5964651336040413 ... Score: -1.2033843552089643
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6116342315734067 ... Score: -1.1582481028760254
#
# Training:
# Epoch: 2 ... Accuracy: 0.6313285394156911 ... Score: -1.0903863782570176
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6293626540727852 ... Score: -1.1057463848639482
#
# Training:
# Epoch: 3 ... Accuracy: 0.6428132670261109 ... Score: -1.05203763569928
#
# Validation:
# Epoch: 3 ... Accuracy: 0.6548842717821999 ... Score: -1.0206399046686065
#
# Training:
# Epoch: 4 ... Accuracy: 0.6562954128581449 ... Score: -1.0039574596052494
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6760560291257878 ... Score: -0.9387026084540816
#
# Training:
# Epoch: 5 ... Accuracy: 0.666748112576473 ... Score: -0.9661260124851454
#
# Validation:
# Epoch: 5 ... Accuracy: 0.6890178819469829 ... Score: -0.8888683783428128
#
# Training:
# ...

# %%
# KNN - k = 100
x = pd.read_csv('../../Data/Missing_KNN/X_train_100.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_100_C.csv')

LR = ANN([26,12], None, 0, device = "cuda:3")
LR.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)

# %%
# Missing Mean
x = pd.read_csv('../../Data/Missing_mean/X_train.csv')
xt = pd.read_csv('../../Data/Missing_mean/X_test.csv')

LR = ANN([26,12], None, 0, device = "cuda:3")
LR.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)

# %%
# Missing MICE
x = pd.read_csv('../../Data/Missing_MICE/X_train_preTrain.csv')
xt = pd.read_csv('../../Data/Missing_MICE/X_test_preTrain.csv')

LR = ANN([26,12], None, 0, device = "cuda:0")
LR.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# Device is cuda:0.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6054646218617339 ... Score: -1.185268335795221
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6168759960814704 ... Score: -1.150875272323191
#
# Training:
# Epoch: 2 ... Accuracy: 0.6260974907540382 ... Score: -1.1146346552915778
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6221981781761291 ... Score: -1.1222740265816677
#
# Training:
# Epoch: 3 ... Accuracy: 0.6371439482414091 ... Score: -1.0774781270744145
#
# Validation:
# Epoch: 3 ... Accuracy: 0.6282075651016917 ... Score: -1.092479310748176
#
# Training:
# Epoch: 4 ... Accuracy: 0.6492232879485968 ... Score: -1.0339398775406639
#
# Validation:
# Epoch: 4 ... Accuracy: 0.635627915137514 ... Score: -1.0598032693404296
#
# Training:
# Epoch: 5 ... Accuracy: 0.6591386155277481 ... Score: -0.9976563654677316
#
# Validation:
# Epoch: 5 ... Accuracy: 0.6430921293114793 ... Score: -1.0277623440995423
#
# Training:
# ...
