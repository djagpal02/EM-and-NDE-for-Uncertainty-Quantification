# %%
import sys
sys.path.insert(0, '../../Models/LSTM')

# %%
from LSTM import LSTM
import pandas as pd
import torch
import utils
import numpy as np

# %%
A = np.load('../penalty_matrix.npy')

# %%
y = pd.read_csv('../../Data/Y_train.csv')
yt = pd.read_csv('../../Data/Y_test.csv')

# %%
# 0
x = pd.read_csv('../../Data/0/X_train_0_WELL.csv')
xt = pd.read_csv('../../Data/0/X_test_0_WELL.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = False, active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6660800282953343 ... Score: -0.96968418066981
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6661061804570643 ... Score: -0.9821847630605471
#
# Training:
# Epoch: 2 ... Accuracy: 0.7047434838288577 ... Score: -0.8226351567819525
#
# Validation:
# Epoch: 2 ... Accuracy: 0.7120538651616394 ... Score: -0.8147736244937347
#
# Training:
# Epoch: 3 ... Accuracy: 0.7086358009450573 ... Score: -0.8076444817690736
#
# Validation:
# Epoch: 3 ... Accuracy: 0.693952597488047 ... Score: -0.8746682774552952
#
# Training:
# Epoch: 4 ... Accuracy: 0.7199283048172977 ... Score: -0.7601088328089185
#
# Validation:
# Epoch: 4 ... Accuracy: 0.7320559121547526 ... Score: -0.7286418200693053
#
# Training:
# Epoch: 5 ... Accuracy: 0.7053509108415043 ... Score: -0.8029971525256918
#
# Validation:
# Epoch: 5 ... Accuracy: 0.6945813168014271 ... Score: -0.8524446946324916
#
# Training:
# ...

# %%
# KNN - k=50
x = pd.read_csv('../../Data/Missing_KNN/X_train_50_well.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_50_C_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = False, active_log = False)
# Out:
# Device is cuda:1.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6754793419284398 ... Score: -0.9167399964630832
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6432164110362172 ... Score: -1.0472151755296595
#
# Training:
# Epoch: 2 ... Accuracy: 0.7015013101115667 ... Score: -0.8274924370638123
#
# Validation:
# Epoch: 2 ... Accuracy: 0.7124047782667817 ... Score: -0.8094578392525551
#
# Training:
# Epoch: 3 ... Accuracy: 0.7221999622387145 ... Score: -0.7485026838705489
#
# Validation:
# Epoch: 3 ... Accuracy: 0.726404749024023 ... Score: -0.7483231105522495
#
# Training:
# Epoch: 4 ... Accuracy: 0.7336359931687955 ... Score: -0.7074285290783257
#
# Validation:
# Epoch: 4 ... Accuracy: 0.7285614024827102 ... Score: -0.7322450762504935
#
# Training:
# Epoch: 5 ... Accuracy: 0.7253806243597881 ... Score: -0.7352359354162413
#
# Validation:
# Epoch: 5 ... Accuracy: 0.7306888131826357 ... Score: -0.7233114134487447
#
# Training:
# ...

# %%
# Missing Mean
x = pd.read_csv('../../Data/Missing_mean/X_train_well.csv')
xt = pd.read_csv('../../Data/Missing_mean/X_test_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = False, active_log = False)

# %%
# Missing MICE
x = pd.read_csv('../../Data/Missing_MICE/X_train_preTrain_well.csv')
xt = pd.read_csv('../../Data/Missing_MICE/X_test_preTrain_well.csv')

Model = LSTM(9, 26, 12, 317, 1, device = "cuda:1")
Model.fit( x=x, y=y, xt = xt, yt = yt, optim = 'adamw',class_weights = 'unbal', lr = 0.00001, weight_decay = 0.1, n_epoch = 100, batchsize = 128, momentum = None, savemodel = False, active_log = False)
