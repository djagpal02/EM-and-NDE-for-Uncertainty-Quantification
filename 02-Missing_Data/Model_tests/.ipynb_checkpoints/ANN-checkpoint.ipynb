# %%
import sys
sys.path.insert(0, '../../Models/ANN')

# %%
from ANN import ANN
import pandas as pd
import torch
import numpy as np
import utils
A = np.load('../penalty_matrix.npy')

# %%
y = pd.read_csv('../../Data/Y_train.csv')
yt = pd.read_csv('../../Data/Y_test.csv')

# %%
# KNN - k = 5
x = pd.read_csv('../../Data/Missing_KNN/X_train_5.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_5_C.csv')

Model = ANN([26,58,12], 'tanh', 0.1227, device = "cuda:2")
Model.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# Device is cuda:2.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6147246800756251 ... Score: -1.153800135154646
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6154138581433772 ... Score: -1.1538105142339128
#
# Training:
# Epoch: 2 ... Accuracy: 0.6345997602756402 ... Score: -1.0752696899046656
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6432529644846695 ... Score: -1.03489300805638
#
# Training:
# Epoch: 3 ... Accuracy: 0.6642406607028896 ... Score: -0.957970066065163
#
# Validation:
# Epoch: 3 ... Accuracy: 0.6817729884637317 ... Score: -0.892581294869358
#
# Training:
# Epoch: 4 ... Accuracy: 0.6865112758444816 ... Score: -0.8775432268470779
#
# Validation:
# Epoch: 4 ... Accuracy: 0.7067024403082187 ... Score: -0.8049343500065796
#
# Training:
# Epoch: 5 ... Accuracy: 0.6985760919803402 ... Score: -0.8371270111942561
#
# Validation:
# Epoch: 5 ... Accuracy: 0.7207901393417455 ... Score: -0.7631802596756978
#
# Training:
# ...

# %%
# KNN - k = 50
x = pd.read_csv('../../Data/Missing_KNN/X_train_50.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_50_C.csv')

Model = ANN([26,58,12], 'tanh', 0.1227, device = "cuda:2")
Model.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 15
# Device is cuda:2.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6193876007999924 ... Score: -1.1363412005525793
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6256342023306479 ... Score: -1.101600309973243
#
# Training:
# Epoch: 2 ... Accuracy: 0.6587507507404886 ... Score: -0.9896323058903334
#
# Validation:
# Epoch: 2 ... Accuracy: 0.6687526501250128 ... Score: -0.9403146155308292
#
# Training:
# Epoch: 3 ... Accuracy: 0.6865659528188971 ... Score: -0.8843005319898745
#
# Validation:
# Epoch: 3 ... Accuracy: 0.7097583085988333 ... Score: -0.8131908601757489
#
# Training:
# Epoch: 4 ... Accuracy: 0.6999122605426177 ... Score: -0.8357072253058707
#
# Validation:
# Epoch: 4 ... Accuracy: 0.7207170324448409 ... Score: -0.7733128755866828
#
# Training:
# Epoch: 5 ... Accuracy: 0.707406423348435 ... Score: -0.8087929118137293
#
# Validation:
# ...

# %%
# KNN - k = 100
x = pd.read_csv('../../Data/Missing_KNN/X_train_100.csv')
xt = pd.read_csv('../../Data/Missing_KNN/X_test_100_C.csv')

Model = ANN([26,58,12], 'tanh', 0.1227, device = "cuda:2")
Model.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)

# %%
# Missing Mean
x = pd.read_csv('../../Data/Missing_Mean/X_train.csv')
xt = pd.read_csv('../../Data/Missing_Mean/X_test.csv')

Model = ANN([26,58,12], 'tanh', 0.1227, device = "cuda:2")
Model.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)

# %%
# Missing MICE
x = pd.read_csv('../../Data/Missing_MICE/X_train_preTrain.csv')
xt = pd.read_csv('../../Data/Missing_MICE/X_test_preTrain.csv')

Model = ANN([26,58,12], 'tanh', 0.1227, device = "cuda:0")
Model.fit( x=x, y=y, xt = xt, yt = yt,class_weights = 'unbal', lr = 0.0001, weight_decay = 0.1, n_epoch = 200, batchsize = 256, savemodel = False, active_log = False)
# Out:
# Device is cuda:0.
#
# Loading Data ...
#
# Starting training...
#
# Training:
# Epoch: 1 ... Accuracy: 0.6153483393150513 ... Score: -1.151282110975463
#
# Validation:
# Epoch: 1 ... Accuracy: 0.6170514526340415 ... Score: -1.144820193587063
#
# Training:
# Epoch: 2 ... Accuracy: 0.6548738115233432 ... Score: -1.0014777733827362
#
# Validation:
# Epoch: 2 ... Accuracy: 0.653707250742035 ... Score: -0.9971680215811559
#
# Training:
# Epoch: 3 ... Accuracy: 0.6797578151764486 ... Score: -0.9095370526206076
#
# Validation:
# Epoch: 3 ... Accuracy: 0.6695860687497258 ... Score: -0.9224189610047812
#
# Training:
# Epoch: 4 ... Accuracy: 0.6922583384521803 ... Score: -0.8663713967660278
#
# Validation:
# Epoch: 4 ... Accuracy: 0.6801938794905912 ... Score: -0.882057557059933
#
# Training:
# Epoch: 5 ... Accuracy: 0.6996260607546618 ... Score: -0.8409078385423119
#
# Validation:
# Epoch: 5 ... Accuracy: 0.6883379878057696 ... Score: -0.8583901130232626
#
# Training:
# ...
