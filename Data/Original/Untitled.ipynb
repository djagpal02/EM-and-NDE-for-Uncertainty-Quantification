# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv', sep=';').drop(['FORCE_2020_LITHOFACIES_CONFIDENCE', 'WELL', 'FORCE_2020_LITHOFACIES_LITHOLOGY'], axis = 1)

# %%
data
# Out:
#           DEPTH_MD         X_LOC      Y_LOC       Z_LOC         GROUP  \
# 0         494.5280  437641.96875  6470972.5 -469.501831  NORDLAND GP.
# 1         494.6800  437641.96875  6470972.5 -469.653809  NORDLAND GP.
# 2         494.8320  437641.96875  6470972.5 -469.805786  NORDLAND GP.
# 3         494.9840  437641.96875  6470972.5 -469.957794  NORDLAND GP.
# 4         495.1360  437641.96875  6470972.5 -470.109772  NORDLAND GP.
# ...            ...           ...        ...         ...           ...
# 1170506  3169.3124           NaN        NaN         NaN  VESTLAND GP.
# 1170507  3169.4644           NaN        NaN         NaN  VESTLAND GP.
# 1170508  3169.6164           NaN        NaN         NaN  VESTLAND GP.
# 1170509  3169.7684           NaN        NaN         NaN  VESTLAND GP.
# 1170510  3169.9204           NaN        NaN         NaN  VESTLAND GP.
#
#          FORMATION       CALI  RSHA      RMED      RDEP  ...         SP   BS  \
# ...

# %%
datat = pd.read_csv('test.csv', sep=';').drop(['WELL'], axis = 1)

# %%
datat.drop(['WELL'], axis = 1)
# Out:
#            DEPTH_MD         X_LOC      Y_LOC        Z_LOC         GROUP  \
# 0        480.628001  423244.50000  6461862.5  -455.624420  NORDLAND GP.
# 1        480.780001  423244.50000  6461862.5  -455.776428  NORDLAND GP.
# 2        480.932001  423244.50000  6461862.5  -455.928436  NORDLAND GP.
# 3        481.084001  423244.50000  6461862.5  -456.080444  NORDLAND GP.
# 4        481.236001  423244.53125  6461862.5  -456.232422  NORDLAND GP.
# ...             ...           ...        ...          ...           ...
# 136781  3224.389600  536225.93750  6794880.5 -3199.876465      BAAT GP.
# 136782  3224.541600  536225.93750  6794880.5 -3200.028320      BAAT GP.
# 136783  3224.693600  536225.93750  6794880.5 -3200.180176      BAAT GP.
# 136784  3224.845600  536225.93750  6794880.5 -3200.332031      BAAT GP.
# 136785  3224.997600  536225.93750  6794880.5 -3200.483887      BAAT GP.
#
#           FORMATION     CALI  RSHA      RMED      RDEP  ...         SP   BS  \
# ...

# %%
datat.mean()
# Out:
# DEPTH_MD     2.501137e+03
# X_LOC        4.678846e+05
# Y_LOC        6.708199e+06
# Z_LOC       -2.397836e+03
# CALI         1.261357e+01
# RSHA         3.137817e+00
# RMED         3.844914e+00
# RDEP         3.662074e+00
# RHOB         2.324925e+00
# GR           6.522326e+01
# SGR                   NaN
# NPHI         3.134422e-01
# PEF          6.113697e+00
# DTC          1.089792e+02
# SP           4.352847e+01
# BS           1.096336e+01
# ROP          2.640694e+01
# DTS          1.853895e+02
# DCAL         1.609791e-01
# DRHO         1.444061e-02
# MUDWEIGHT    6.028683e+00
# RMIC         4.906861e+00
# ROPA         2.266906e+01
# RXO          5.280645e+00
# dtype: float64

# %%
datat.isna().sum()
# Out:
# DEPTH_MD          0
# X_LOC            59
# Y_LOC            59
# Z_LOC            59
# GROUP             0
# FORMATION      7074
# CALI           5645
# RSHA          97689
# RMED            587
# RDEP             59
# RHOB          16960
# GR                0
# SGR          136786
# NPHI          32743
# PEF           23283
# DTC             823
# SP            70159
# BS            69822
# ROP           68470
# DTS           93566
# DCAL         123271
# DRHO          25230
# MUDWEIGHT    116517
# RMIC         125470
# ROPA          80996
# RXO          106938
# dtype: int64

# %%
datat = datat.fillna(datat.mean())

# %%
datat.isna().sum()
# Out:
# DEPTH_MD          0
# X_LOC             0
# Y_LOC             0
# Z_LOC             0
# GROUP             0
# FORMATION      7074
# CALI              0
# RSHA              0
# RMED              0
# RDEP              0
# RHOB              0
# GR                0
# SGR          136786
# NPHI              0
# PEF               0
# DTC               0
# SP                0
# BS                0
# ROP               0
# DTS               0
# DCAL              0
# DRHO              0
# MUDWEIGHT         0
# RMIC              0
# ROPA              0
# RXO               0
# dtype: int64

# %%
datat.to_numpy().values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-268d28766510> in <module>
# ----> 1 datat.to_numpy().values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
data['GROUP']
# Out:
# 0          NORDLAND GP.
# 1          NORDLAND GP.
# 2          NORDLAND GP.
# 3          NORDLAND GP.
# 4          NORDLAND GP.
#                ...
# 1170506    VESTLAND GP.
# 1170507    VESTLAND GP.
# 1170508    VESTLAND GP.
# 1170509    VESTLAND GP.
# 1170510    VESTLAND GP.
# Name: GROUP, Length: 1170511, dtype: object

# %%
datat['GROUP']
# Out:
# 0         NORDLAND GP.
# 1         NORDLAND GP.
# 2         NORDLAND GP.
# 3         NORDLAND GP.
# 4         NORDLAND GP.
#               ...
# 136781        BAAT GP.
# 136782        BAAT GP.
# 136783        BAAT GP.
# 136784        BAAT GP.
# 136785        BAAT GP.
# Name: GROUP, Length: 136786, dtype: object

# %%
data['GROUP'].append(datat['GROUP'])
# Out:
# 0         NORDLAND GP.
# 1         NORDLAND GP.
# 2         NORDLAND GP.
# 3         NORDLAND GP.
# 4         NORDLAND GP.
#               ...
# 136781        BAAT GP.
# 136782        BAAT GP.
# 136783        BAAT GP.
# 136784        BAAT GP.
# 136785        BAAT GP.
# Name: GROUP, Length: 1307297, dtype: object

# %%
pd.concat([data['GROUP'], datat['GROUP']], ignore_index=True)
# Out:
# 0          NORDLAND GP.
# 1          NORDLAND GP.
# 2          NORDLAND GP.
# 3          NORDLAND GP.
# 4          NORDLAND GP.
#                ...
# 1307292        BAAT GP.
# 1307293        BAAT GP.
# 1307294        BAAT GP.
# 1307295        BAAT GP.
# 1307296        BAAT GP.
# Name: GROUP, Length: 1307297, dtype: object

# %%
1170511+136786
# Out:
# 1307297
